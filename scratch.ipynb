# %%
pwd
# Out:
# '/home/vikas'

# %%
cd /home/vikas/Documents/datasets
# Out:
# /home/vikas/Documents/datasets

# %%
pwd
# Out:
# '/home/vikas/Documents/datasets'

# %%
import pandas as pd

# %%
data=pd.read_csv('data.csv')
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M       17.990         10.38          122.80     1001.0
# 1      842517         M       20.570         17.77          132.90     1326.0
# 2    84300903         M       19.690         21.25          130.00     1203.0
# 3    84348301         M       11.420         20.38           77.58      386.1
# 4    84358402         M       20.290         14.34          135.10     1297.0
# 5      843786         M       12.450         15.70           82.57      477.1
# 6      844359         M       18.250         19.98          119.60     1040.0
# 7    84458202         M       13.710         20.83           90.20      577.9
# 8      844981         M       13.000         21.82           87.50      519.8
# 9    84501001         M       12.460         24.04           83.97      475.9
# 10     845636         M       16.020         23.24          102.70      797.8
# ...

# %%
data.shape
# Out:
# (150, 5)

# %%
data.describe()
# Out:
#         Feature-1   Feature-2   Feature-3   Feature-4
# count  142.000000  137.000000  143.000000  141.000000
# mean     5.859859    3.067153    3.788811    1.194326
# std      0.840387    0.437928    1.749531    0.770693
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
data.shape[0]
# Out:
# 150

# %%
data.shape[1]
# Out:
# 5

# %%
data.head(20)
# Out:
#     Feature-1  Feature-2  Feature-3  Feature-4 Class_Label
# 0         5.1        3.5        1.4        0.2     Class-1
# 1         4.9        3.0        1.4        0.2     Class-1
# 2         4.7        3.2        1.3        0.2     Class-1
# 3         4.6        3.1        1.5        0.2     Class-1
# 4         5.0        3.6        1.4        0.2     Class-1
# 5         5.4        3.9        1.7        0.4     Class-1
# 6         4.6        3.4        1.4        0.3     Class-1
# 7         5.0        3.4        1.5        0.2     Class-1
# 8         4.4        2.9        1.4        0.2     Class-1
# 9         4.9        3.1        1.5        0.1     Class-1
# 10        5.4        3.7        1.5        0.2     Class-1
# 11        4.8        3.4        1.6        0.2     Class-1
# 12        4.8        3.0        1.4        0.1     Class-1
# 13        4.3        3.0        1.1        0.1     Class-1
# 14        5.8        4.0        1.2        0.2     Class-1
# ...

# %%
data.columns
# Out:
# Index(['Feature-1', 'Feature-2', 'Feature-3', 'Feature-4', 'Class_Label'], dtype='object')

# %%
print('Number of records\n:')
print(data['Class_Label'].value_counts())
# Out:
# Number of records
# :
# Class-1    50
# Class-3    50
# Class-2    50
# Name: Class_Label, dtype: int64

# %%
print('Total number of class\n:')
print(data.Class_Label.nunique())
# Out:
# Total number of class
# :
# 3

# %%
data.tail(20)
# Out:
#      Feature-1  Feature-2  Feature-3  Feature-4 Class_Label
# 130        7.4        2.8        6.1        1.9     Class-3
# 131        7.9        3.8        6.4        2.0     Class-3
# 132        6.4        2.8        5.6        2.2     Class-3
# 133        6.3        2.8        5.1        NaN     Class-3
# 134        6.1        2.6        5.6        NaN     Class-3
# 135        7.7        3.0        6.1        NaN     Class-3
# 136        6.3        3.4        5.6        2.4     Class-3
# 137        6.4        3.1        5.5        1.8     Class-3
# 138        6.0        3.0        4.8        1.8     Class-3
# 139        6.9        3.1        5.4        2.1     Class-3
# 140        6.7        3.1        5.6        2.4     Class-3
# 141        6.9        3.1        NaN        2.3     Class-3
# 142        5.8        2.7        NaN        1.9     Class-3
# 143        6.8        3.2        NaN        2.3     Class-3
# 144        6.7        3.3        5.7        2.5     Class-3
# ...

# %%
import numpy as np
class_maping={label:idx for idx,label in enumerate(np.unique(data['Class_Label']))}
#class_maping={'class-1':0,'class-2':1,'class-3':2}
print("\n",class_maping)
print("\n")
data['Class_Label']=data['Class_Label'].map(class_maping)
print(data)
print()
print(data.Class_Label.value_counts)
# Out:
#  {'class-1': 0, 'class-2': 1, 'class-3': 2}
#
#
#      Feature-1  Feature-2  Feature-3  Feature-4  Class_Label
# 0          5.1        3.5        1.4        0.2          NaN
# 1          4.9        3.0        1.4        0.2          NaN
# 2          4.7        3.2        1.3        0.2          NaN
# 3          4.6        3.1        1.5        0.2          NaN
# 4          5.0        3.6        1.4        0.2          NaN
# 5          5.4        3.9        1.7        0.4          NaN
# 6          4.6        3.4        1.4        0.3          NaN
# 7          5.0        3.4        1.5        0.2          NaN
# 8          4.4        2.9        1.4        0.2          NaN
# 9          4.9        3.1        1.5        0.1          NaN
# 10         5.4        3.7        1.5        0.2          NaN
# 11         4.8        3.4        1.6        0.2          NaN
# 12         4.8        3.0        1.4        0.1          NaN
# 13         4.3        3.0        1.1        0.1          NaN
# ...

# %%
print('Number of missing value')
print(data.isnull().sum())
# Out:
# Number of missing value
# Feature-1        8
# Feature-2       13
# Feature-3        7
# Feature-4        9
# Class_Label    150
# dtype: int64

# %%
df1=data.dropna()
print(df1)
# Out:
# Empty DataFrame
# Columns: [Feature-1, Feature-2, Feature-3, Feature-4, Class_Label]
# Index: []

# %%
print('total num of row now left:',df1.shape[0])
# Out:
# total num of row now left: 0

# %%
print(df1.Class_Label.value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of Series([], Name: Class_Label, dtype: float64)>

# %%
from sklearn.impute import SimpleImputer
imput=SimpleImputer(missing_values=np.nan,strategy='mean')
imput=imput.fit(data)
imputed_data=imput.transform(data.values)
print("Imputed_data:\n",imputed_data)
imputed_data=pd.DataFrame(imputed_data)
# Out:
# Imputed_data:
#  [[5.1        3.5        1.4        0.2       ]
#  [4.9        3.         1.4        0.2       ]
#  [4.7        3.2        1.3        0.2       ]
#  [4.6        3.1        1.5        0.2       ]
#  [5.         3.6        1.4        0.2       ]
#  [5.4        3.9        1.7        0.4       ]
#  [4.6        3.4        1.4        0.3       ]
#  [5.         3.4        1.5        0.2       ]
#  [4.4        2.9        1.4        0.2       ]
#  [4.9        3.1        1.5        0.1       ]
#  [5.4        3.7        1.5        0.2       ]
#  [4.8        3.4        1.6        0.2       ]
#  [4.8        3.         1.4        0.1       ]
#  [4.3        3.         1.1        0.1       ]
#  [5.8        4.         1.2        0.2       ]
#  [5.7        4.4        1.5        0.4       ]
#  [5.4        3.9        1.3        0.4       ]
#  [5.1        3.5        1.4        0.3       ]
#  [5.7        3.8        1.7        0.3       ]
#  [5.1        3.8        1.5        0.3       ]
# ...

# %%
print('total num of row now left:',data.shape[0])
print(data.Class_Label.value_counts)
# Out:
# total num of row now left: 150
# <bound method IndexOpsMixin.value_counts of 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
#        ..
# 120   NaN
# 121   NaN
# 122   NaN
# 123   NaN
# 124   NaN
# 125   NaN
# 126   NaN
# 127   NaN
# 128   NaN
# 129   NaN
# 130   NaN
# 131   NaN
# 132   NaN
# 133   NaN
# 134   NaN
# 135   NaN
# 136   NaN
# 137   NaN
# 138   NaN
# 139   NaN
# 140   NaN
# 141   NaN
# 142   NaN
# 143   NaN
# 144   NaN
# 145   NaN
# 146   NaN
# 147   NaN
# 148   NaN
# 149   NaN
# Name: Class_Label, Length: 150, dtype: float64>

# %%
y=data.Class_Label

# %%
x=data.iloc[:,0:4].values
print(x)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [nan nan nan 0.2]
#  [nan nan nan 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 nan nan nan]
#  [5.  nan nan nan]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (105, 4)
# (45, 4)

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler()

# %%
X_train_std=st.fit_transform(X_train)
X_test_std=st.transform(X_test)

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()

# %%
X_train_norm=mms.fit_transform(X_train)
X_test_norm=mms.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(penalty='l1')

# %%
lr.fit(X_train_std,y_train)
# Out:
# /home/vikas/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-3b3a2fb4e35b> in <module>
# ----> 1 lr.fit(X_train_std,y_train)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1286
#    1287         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1288                          accept_large_sparse=solver != 'liblinear')
#    1289         check_classification_targets(y)
#    1290         self.classes_ = np.unique(y)
#
# ...

# %%
y_pre=lr.predict(X_test_std)

lr.score(X_test_std,y_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-111-697c743f12c8> in <module>
# ----> 1 y_pre=lr.predict(X_test_std)
#       2 lr.score(X_test_std,y_test)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     279             Predicted class label per sample.
#     280         """
# --> 281         scores = self.decision_function(X)
#     282         if len(scores.shape) == 1:
#     283             indices = (scores > 0).astype(np.int)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/base.py in decision_function(self, X)
#     253         if not hasattr(self, 'coef_') or self.coef_ is None:
#     254             raise NotFittedError("This %(name)s instance is not fitted "
# --> 255                                  "yet" % {'name': type(self).__name__})
#     256
# ...

# %%
from sklearn.metrics import confusion_matrix,classification_report
cmat= confusion_matrix(y_pre,y_test)
print(cmat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-112-e725311bed58> in <module>
#       1 from sklearn.metrics import confusion_matrix,classification_report
# ----> 2 cmat= confusion_matrix(y_pre,y_test)
#       3 print(cmat)
#
# NameError: name 'y_pre' is not defined
